# %%
'''Trains a simple deep NN on the MNIST dataset.
Gets to 98.40% test accuracy after 20 epochs
(there is *a lot* of margin for parameter tuning).
2 seconds per epoch on a K520 GPU.
'''

from __future__ import print_function

import tensorflow.keras as keras
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import RMSprop


batch_size = 128
num_classes = 10
epochs = 20

# the data, shuffled and split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))

model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 60000 train samples
# 10000 test samples
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               401920
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 669,706
# Trainable params: 669,706
# Non-trainable params: 0
# _________________________________________________________________
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 40s 673us/sample - loss: 0.2418 - accuracy: 0.9256 - val_loss: 0.1186 - val_accuracy: 0.9648
# Epoch 2/20
# 60000/60000 [==============================] - 39s 655us/sample - loss: 0.1027 - accuracy: 0.9686 - val_loss: 0.1001 - val_accuracy: 0.9676
# Epoch 3/20
# 60000/60000 [==============================] - 39s 655us/sample - loss: 0.0751 - accuracy: 0.9768 - val_loss: 0.0900 - val_accuracy: 0.9746
# Epoch 4/20
# 60000/60000 [==============================] - 40s 659us/sample - loss: 0.0614 - accuracy: 0.9818 - val_loss: 0.0616 - val_accuracy: 0.9830
# Epoch 5/20
# 60000/60000 [==============================] - 37s 619us/sample - loss: 0.0503 - accuracy: 0.9853 - val_loss: 0.0767 - val_accuracy: 0.9793
# Epoch 6/20
# 60000/60000 [==============================] - 36s 594us/sample - loss: 0.0426 - accuracy: 0.9870 - val_loss: 0.0919 - val_accuracy: 0.9779
# Epoch 7/20
# 60000/60000 [==============================] - 39s 654us/sample - loss: 0.0368 - accuracy: 0.9884 - val_loss: 0.0834 - val_accuracy: 0.9812
# Epoch 8/20
# 60000/60000 [==============================] - 40s 664us/sample - loss: 0.0349 - accuracy: 0.9895 - val_loss: 0.0805 - val_accuracy: 0.9822
# Epoch 9/20
# 60000/60000 [==============================] - 38s 627us/sample - loss: 0.0326 - accuracy: 0.9904 - val_loss: 0.0884 - val_accuracy: 0.9809
# Epoch 10/20
# 60000/60000 [==============================] - 39s 650us/sample - loss: 0.0275 - accuracy: 0.9919 - val_loss: 0.0950 - val_accuracy: 0.9833
# Epoch 11/20
# 60000/60000 [==============================] - 42s 697us/sample - loss: 0.0261 - accuracy: 0.9924 - val_loss: 0.0848 - val_accuracy: 0.9838
# Epoch 12/20
# 60000/60000 [==============================] - 38s 637us/sample - loss: 0.0247 - accuracy: 0.9928 - val_loss: 0.1031 - val_accuracy: 0.9820
# Epoch 13/20
# 60000/60000 [==============================] - 38s 639us/sample - loss: 0.0247 - accuracy: 0.9927 - val_loss: 0.1018 - val_accuracy: 0.9832
# Epoch 14/20
# 60000/60000 [==============================] - 40s 665us/sample - loss: 0.0225 - accuracy: 0.9934 - val_loss: 0.0995 - val_accuracy: 0.9834
# Epoch 15/20
# 60000/60000 [==============================] - 38s 637us/sample - loss: 0.0212 - accuracy: 0.9944 - val_loss: 0.1036 - val_accuracy: 0.9825
# Epoch 16/20
# 60000/60000 [==============================] - 40s 659us/sample - loss: 0.0211 - accuracy: 0.9943 - val_loss: 0.1105 - val_accuracy: 0.9823
# Epoch 17/20
# 60000/60000 [==============================] - 38s 637us/sample - loss: 0.0202 - accuracy: 0.9949 - val_loss: 0.1140 - val_accuracy: 0.9817
# Epoch 18/20
# 60000/60000 [==============================] - 39s 642us/sample - loss: 0.0175 - accuracy: 0.9955 - val_loss: 0.1177 - val_accuracy: 0.9839
# Epoch 19/20
# 60000/60000 [==============================] - 40s 662us/sample - loss: 0.0175 - accuracy: 0.9950 - val_loss: 0.1304 - val_accuracy: 0.9840
# Epoch 20/20
# 60000/60000 [==============================] - 40s 674us/sample - loss: 0.0182 - accuracy: 0.9954 - val_loss: 0.1199 - val_accuracy: 0.9830
# Test loss: 0.11987108501661664
# Test accuracy: 0.983
